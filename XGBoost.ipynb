# %% [markdown]
# Required dependency packages

# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.0.0-py3-none-macosx_12_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.10/site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.10/site-packages (from xgboost) (1.13.1)
# Downloading xgboost-3.0.0-py3-none-macosx_12_0_arm64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 35.0 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-3.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import xarray as xr
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt

# %% [markdown]
# Data reading and preprocessing

# %%
import xarray as xr
import pandas as pd

# 1. Read NetCDF file, force decode_times=True
file_path = 'preprocessed_merged_dataset.nc'
ds = xr.open_dataset(file_path, decode_times=True)

# 2. Confirm whether the time variable is decoded successfully
print(ds['time'].values[:10])

# 3. Convert to dataframe
df = ds[['TREFHT', 'TREFMXAV_U', 'FLNS', 'FSNS', 'PRECT', 'PRSN', 'QBOT', 'UBOT', 'VBOT']].to_dataframe().reset_index()

# 4. Force conversion of time columns to datetime
df['time'] = pd.to_datetime(df['time'], errors='coerce')

# 5. Check the time column
print(f"Min date: {df['time'].min()}")
print(f"Max date: {df['time'].max()}")
# Out:
# ['2006-01-02T00:00:00.000000000' '2006-01-03T00:00:00.000000000'
#  '2006-01-04T00:00:00.000000000' '2006-01-05T00:00:00.000000000'
#  '2006-01-06T00:00:00.000000000' '2006-01-07T00:00:00.000000000'
#  '2006-01-08T00:00:00.000000000' '2006-01-09T00:00:00.000000000'
#  '2006-01-10T00:00:00.000000000' '2006-01-11T00:00:00.000000000']
# Min date: 2006-01-02 00:00:00
# Max date: 2080-12-12 00:00:00

# %% [markdown]
# Data cleaning and screening (example based on a certain latitude and longitude point)

# %%
# View the actual matching latitude and longitude
lat_select = 50.41885
lon_select = 355.0

# Using isclose to solve floating point precision errors
df_sel = df[
    np.isclose(df['lat'], lat_select, atol=1e-5) &
    np.isclose(df['lon'], lon_select, atol=1e-5)
].copy()

# Verify that time is normal
df_sel['time'] = pd.to_datetime(df_sel['time'], errors='coerce')

# Print information
print(f"Min date: {df_sel['time'].min()}")
print(f"Max date: {df_sel['time'].max()}")
print(f"✅ Samples: {len(df_sel)}")
# Out:
# Min date: 2006-01-02 00:00:00
# Max date: 2080-12-12 00:00:00
# ✅ Samples: 27374

# %% [markdown]
# 1️⃣ Sample division

# %%
# Divide into training set and test set
train_df = df_sel[df_sel['time'] < '2015-01-01']
test_df = df_sel[df_sel['time'] >= '2015-01-01']

print(f"✅ Train samples: {len(train_df)}")
print(f"✅ Test samples: {len(test_df)}")
# Out:
# ✅ Train samples: 3286
# ✅ Test samples: 24088

# %% [markdown]
# Features & Tags

# %%
# Define input features (X) and prediction targets (y)
features = ['TREFMXAV_U', 'FLNS', 'FSNS', 'PRECT', 'PRSN', 'QBOT', 'UBOT', 'VBOT']
target = 'TREFHT'

X_train = train_df[features]
y_train = train_df[target]

X_test = test_df[features]
y_test = test_df[target]

# %% [markdown]
# XGBoost regression model training and prediction

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Initialize the XGBoost model
model = XGBRegressor(
    n_estimators=500,
    learning_rate=0.01,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

# Train the model
model.fit(X_train, y_train)

# Predict test set
y_pred = model.predict(X_test)

# Error evaluation
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print(f"✅ MAE: {mae:.2f} °C")
print(f"✅ RMSE: {rmse:.2f} °C")
# Out:
# ✅ MAE: 0.41 °C
# ✅ RMSE: 0.61 °C

# %% [markdown]
# Prediction vs. actual comparison chart

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))

# Real value
plt.plot(test_df['time'], y_test, label='Real TREFHT', color='blue')

# Prediction value
plt.plot(test_df['time'], y_pred, label='Predicted TREFHT (XGBoost)', color='red')

plt.title(f'XGBoost TREFHT Prediction at lat {lat_select}, lon {lon_select} (2017-2080)')
plt.xlabel('Year')
plt.ylabel('TREFHT (°C)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 5️⃣ Feature Importance Analysis

# %%
importances = model.feature_importances_
feature_importance = pd.Series(importances, index=features).sort_values(ascending=False)

plt.figure(figsize=(8, 6))
feature_importance.plot(kind='bar')
plt.title('Feature Importance in XGBoost Model')
plt.ylabel('Importance Score')
plt.xlabel('Feature')
plt.grid(True)
plt.show()

# %% [markdown]
# Model Optimization

# %%
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBRegressor

param_grid = {
    'n_estimators': [500, 1000, 1500],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'max_depth': [4, 6, 8, 10],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'gamma': [0, 0.1, 0.5, 1],
    'min_child_weight': [1, 3, 5, 10],
    'reg_alpha': [0, 0.01, 0.1, 1],
    'reg_lambda': [1, 3, 5, 10]
}

xgb = XGBRegressor(objective='reg:squarederror', random_state=42)

random_search = RandomizedSearchCV(
    estimator=xgb,
    param_distributions=param_grid,
    n_iter=50,
    cv=3,
    verbose=2,
    scoring='neg_mean_absolute_error',
    random_state=42,
    n_jobs=-1
)


random_search.fit(X_train, y_train)

print("Best Parameters:", random_search.best_params_)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=500, reg_alpha=0.01, reg_lambda=1, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=500, reg_alpha=0.01, reg_lambda=1, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=500, reg_alpha=0.01, reg_lambda=1, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=1500, reg_alpha=0, reg_lambda=3, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=1500, reg_alpha=0, reg_lambda=3, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=10, min_child_weight=3, n_estimators=1500, reg_alpha=0.01, reg_lambda=1, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=1500, reg_alpha=0, reg_lambda=3, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=10, min_child_weight=3, n_estimators=1500, reg_alpha=0.01, reg_lambda=1, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=10, min_child_weight=3, n_estimators=1500, reg_alpha=0.01, reg_lambda=1, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=10, min_child_weight=3, n_estimators=500, reg_alpha=0.01, reg_lambda=10, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=10, min_child_weight=3, n_estimators=500, reg_alpha=0.01, reg_lambda=10, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=10, min_child_weight=3, n_estimators=500, reg_alpha=0.01, reg_lambda=10, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=1500, reg_alpha=1, reg_lambda=5, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=1500, reg_alpha=1, reg_lambda=5, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=1500, reg_alpha=1, reg_lambda=5, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=1000, reg_alpha=0.01, reg_lambda=5, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=1000, reg_alpha=0.01, reg_lambda=5, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=1000, reg_alpha=0.01, reg_lambda=5, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=8, min_child_weight=10, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=8, min_child_weight=10, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, reg_alpha=1, reg_lambda=5, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, reg_alpha=1, reg_lambda=5, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, reg_alpha=1, reg_lambda=5, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=10, min_child_weight=10, n_estimators=1000, reg_alpha=1, reg_lambda=5, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=10, min_child_weight=10, n_estimators=1000, reg_alpha=1, reg_lambda=5, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=10, min_child_weight=10, n_estimators=1000, reg_alpha=1, reg_lambda=5, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=8, min_child_weight=10, n_estimators=1000, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=1000, reg_alpha=0.01, reg_lambda=10, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=4, min_child_weight=5, n_estimators=1000, reg_alpha=0.01, reg_lambda=5, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=1000, reg_alpha=0.01, reg_lambda=10, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=1000, reg_alpha=0.01, reg_lambda=10, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=500, reg_alpha=1, reg_lambda=3, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=4, min_child_weight=5, n_estimators=1000, reg_alpha=0.01, reg_lambda=5, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=500, reg_alpha=1, reg_lambda=3, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=4, min_child_weight=5, n_estimators=1000, reg_alpha=0.01, reg_lambda=5, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=500, reg_alpha=1, reg_lambda=3, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=1500, reg_alpha=0.01, reg_lambda=10, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.2, max_depth=10, min_child_weight=1, n_estimators=500, reg_alpha=0.01, reg_lambda=5, subsample=0.6; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=1500, reg_alpha=0.01, reg_lambda=10, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.2, max_depth=10, min_child_weight=1, n_estimators=500, reg_alpha=0.01, reg_lambda=5, subsample=0.6; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=1500, reg_alpha=0.01, reg_lambda=10, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, reg_alpha=0.01, reg_lambda=5, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.2, max_depth=10, min_child_weight=1, n_estimators=500, reg_alpha=0.01, reg_lambda=5, subsample=0.6; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, reg_alpha=0.01, reg_lambda=5, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, reg_alpha=0.01, reg_lambda=5, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=1500, reg_alpha=0.01, reg_lambda=10, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=1500, reg_alpha=0.01, reg_lambda=10, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.2, max_depth=6, min_child_weight=3, n_estimators=500, reg_alpha=0.1, reg_lambda=3, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=1500, reg_alpha=0.01, reg_lambda=10, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.2, max_depth=6, min_child_weight=3, n_estimators=500, reg_alpha=0.1, reg_lambda=3, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.2, max_depth=6, min_child_weight=3, n_estimators=500, reg_alpha=0.1, reg_lambda=3, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=1500, reg_alpha=0.1, reg_lambda=3, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=1500, reg_alpha=0.1, reg_lambda=3, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=1500, reg_alpha=0.1, reg_lambda=3, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.3s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=10, n_estimators=500, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=1500, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=10, n_estimators=500, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=10, n_estimators=500, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=1500, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=500, reg_alpha=0.01, reg_lambda=3, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=1500, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=500, reg_alpha=0.01, reg_lambda=3, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=6, min_child_weight=1, n_estimators=1500, reg_alpha=1, reg_lambda=5, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=500, reg_alpha=0.01, reg_lambda=3, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=6, min_child_weight=1, n_estimators=1500, reg_alpha=1, reg_lambda=5, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=6, min_child_weight=1, n_estimators=1500, reg_alpha=1, reg_lambda=5, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=1500, reg_alpha=0.1, reg_lambda=5, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=1500, reg_alpha=0.1, reg_lambda=5, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=1500, reg_alpha=0.1, reg_lambda=5, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=1000, reg_alpha=0, reg_lambda=10, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.2, max_depth=4, min_child_weight=10, n_estimators=1000, reg_alpha=0.1, reg_lambda=3, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=10, n_estimators=500, reg_alpha=1, reg_lambda=1, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=10, n_estimators=500, reg_alpha=1, reg_lambda=1, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.2, max_depth=4, min_child_weight=10, n_estimators=1000, reg_alpha=0.1, reg_lambda=3, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.2, max_depth=4, min_child_weight=10, n_estimators=1000, reg_alpha=0.1, reg_lambda=3, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=10, n_estimators=500, reg_alpha=1, reg_lambda=1, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.2, max_depth=4, min_child_weight=5, n_estimators=500, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.2, max_depth=4, min_child_weight=5, n_estimators=500, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=1500, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.2, max_depth=4, min_child_weight=5, n_estimators=500, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=1500, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=1500, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=10, min_child_weight=10, n_estimators=1500, reg_alpha=1, reg_lambda=10, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=10, min_child_weight=10, n_estimators=1500, reg_alpha=1, reg_lambda=10, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=1500, reg_alpha=1, reg_lambda=3, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=1500, reg_alpha=1, reg_lambda=3, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=1500, reg_alpha=1, reg_lambda=3, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=10, n_estimators=500, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=10, min_child_weight=10, n_estimators=1500, reg_alpha=1, reg_lambda=10, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=10, n_estimators=500, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=10, n_estimators=500, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=8, min_child_weight=5, n_estimators=1500, reg_alpha=0.01, reg_lambda=1, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=8, min_child_weight=5, n_estimators=1500, reg_alpha=0.01, reg_lambda=1, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=8, min_child_weight=5, n_estimators=1500, reg_alpha=0.01, reg_lambda=1, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=8, min_child_weight=5, n_estimators=1000, reg_alpha=1, reg_lambda=10, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1, n_estimators=1000, reg_alpha=0.01, reg_lambda=1, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=8, min_child_weight=5, n_estimators=1000, reg_alpha=1, reg_lambda=10, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=8, min_child_weight=5, n_estimators=1000, reg_alpha=1, reg_lambda=10, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1, n_estimators=1000, reg_alpha=0.01, reg_lambda=1, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=1, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=1000, reg_alpha=0.01, reg_lambda=1, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=1, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=1000, reg_alpha=0.01, reg_lambda=1, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1, n_estimators=500, reg_alpha=1, reg_lambda=5, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=1, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=1000, reg_alpha=0.01, reg_lambda=1, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1, n_estimators=500, reg_alpha=1, reg_lambda=5, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1, n_estimators=1000, reg_alpha=0.01, reg_lambda=1, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1, n_estimators=500, reg_alpha=1, reg_lambda=5, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=8, min_child_weight=10, n_estimators=500, reg_alpha=0, reg_lambda=5, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=8, min_child_weight=10, n_estimators=500, reg_alpha=0, reg_lambda=5, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=8, min_child_weight=10, n_estimators=500, reg_alpha=0, reg_lambda=5, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=1500, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=10, n_estimators=500, reg_alpha=0.01, reg_lambda=3, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=1500, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=10, n_estimators=500, reg_alpha=0.01, reg_lambda=3, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=10, n_estimators=500, reg_alpha=0.01, reg_lambda=3, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=8, min_child_weight=10, n_estimators=1500, reg_alpha=0.1, reg_lambda=5, subsample=0.6; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=1500, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=8, min_child_weight=10, n_estimators=1500, reg_alpha=0.1, reg_lambda=5, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_depth=10, min_child_weight=10, n_estimators=1500, reg_alpha=0.01, reg_lambda=5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_depth=10, min_child_weight=10, n_estimators=1500, reg_alpha=0.01, reg_lambda=5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=8, min_child_weight=10, n_estimators=1500, reg_alpha=0.1, reg_lambda=5, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_depth=10, min_child_weight=10, n_estimators=1500, reg_alpha=0.01, reg_lambda=5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=500, reg_alpha=0.01, reg_lambda=5, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=500, reg_alpha=0.01, reg_lambda=5, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=500, reg_alpha=0.01, reg_lambda=5, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=10, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=10, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1500, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1500, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1500, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=10, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=8, min_child_weight=10, n_estimators=1500, reg_alpha=0.01, reg_lambda=10, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=8, min_child_weight=10, n_estimators=1500, reg_alpha=0.01, reg_lambda=10, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=8, min_child_weight=10, n_estimators=1500, reg_alpha=0.01, reg_lambda=10, subsample=0.8; total time=   1.1s
# Best Parameters: {'subsample': 0.6, 'reg_lambda': 5, 'reg_alpha': 0.1, 'n_estimators': 1500, 'min_child_weight': 10, 'max_depth': 8, 'learning_rate': 0.01, 'gamma': 0.1, 'colsample_bytree': 1.0}

# %%
best_xgb = XGBRegressor(
    subsample=0.6,
    reg_lambda=5,
    reg_alpha=0.1,
    n_estimators=1500,
    min_child_weight=10,
    max_depth=8,
    learning_rate=0.01,
    gamma=0.1,
    colsample_bytree=1.0,
    objective='reg:squarederror',
    random_state=42
)

best_xgb.fit(X_train, y_train)

# 预测
y_pred_optimized = best_xgb.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae_optimized = mean_absolute_error(y_test, y_pred_optimized)
rmse_optimized = np.sqrt(mean_squared_error(y_test, y_pred_optimized))

print(f"✅ Optimized MAE: {mae_optimized:.2f} °C")
print(f"✅ Optimized RMSE: {rmse_optimized:.2f} °C")
# Out:
# ✅ Optimized MAE: 0.37 °C
# ✅ Optimized RMSE: 0.56 °C

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
plt.plot(test_df['time'], y_test, label='Real TREFHT', color='blue')
plt.plot(test_df['time'], y_pred_optimized, label='Optimized XGBoost Prediction', color='red')
plt.title('Optimized XGBoost TREFHT Prediction vs Real TREFHT (2017-2080)')
plt.xlabel('Year')
plt.ylabel('TREFHT (°C)')
plt.legend()
plt.grid(True)
plt.show()
