# %% [markdown]
# #### Part 2: External Dataset

# %%
# import libraries
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import xarray as xr
import zarr 
import gcsfs
import cdsapi
import climetlab as cml

# %%
# File paths
historical_file = "/Users/taniadiamanta/UOM/Semester 2/EarthAndEnvironmentalDS/Earth-Env-DS-Coursework2_Group2/raw_external_data/hfls_Amon_HadGEM3-GC31-LL_historical_r1i1p1f3_gn_20060116-20141216.nc"
projected_file = "/Users/taniadiamanta/UOM/Semester 2/EarthAndEnvironmentalDS/Earth-Env-DS-Coursework2_Group2/raw_external_data/hfls_Amon_HadGEM3-GC31-LL_ssp245_r1i1p1f3_gn_20150116-20801216.nc"

# Open datasets
ds_hist = xr.open_dataset(historical_file, engine="netcdf4")
ds_proj = xr.open_dataset(projected_file, engine="netcdf4")

# %%
ds_hist
# Out:
# <xarray.Dataset> Size: 17kB
# Dimensions:    (time: 108, bnds: 2, lat: 8, lon: 4)
# Coordinates:
#   * time       (time) object 864B 2006-01-16 00:00:00 ... 2014-12-16 00:00:00
#   * lat        (lat) float64 64B 49.38 50.62 51.88 53.12 54.38 55.62 56.88 58.12
#   * lon        (lon) float64 32B 353.4 355.3 357.2 359.1
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) object 2kB ...
#     lat_bnds   (lat, bnds) float64 128B ...
#     lon_bnds   (lon, bnds) float64 64B ...
#     hfls       (time, lat, lon) float32 14kB ...
# Attributes: (12/46)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  0.0
#     creation_date:          2019-06-19T12:05:32Z
#     ...                     ...
#     title:                  HadGEM3-GC31-LL output prepared for CMIP6
#     variable_id:            hfls
# ...

# %%
ds_proj
# Out:
# <xarray.Dataset> Size: 273kB
# Dimensions:    (time: 792, bnds: 2, lat: 8, lon: 4)
# Coordinates:
#   * time       (time) object 6kB 2015-01-16 00:00:00 ... 2080-12-16 00:00:00
#   * lat        (lat) float64 64B 49.38 50.62 51.88 53.12 54.38 55.62 56.88 58.12
#   * lon        (lon) float64 32B 353.4 355.3 357.2 359.1
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) object 13kB ...
#     lat_bnds   (time, lat, bnds) float64 101kB ...
#     lon_bnds   (time, lon, bnds) float64 51kB ...
#     hfls       (time, lat, lon) float32 101kB ...
# Attributes: (12/47)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            ScenarioMIP
#     branch_method:          standard
#     branch_time_in_child:   59400.0
#     branch_time_in_parent:  59400.0
#     creation_date:          2019-09-06T15:29:46Z
#     ...                     ...
#     variable_id:            hfls
#     variable_name:          hfls
#     variant_label:          r1i1p1f3
# ...
